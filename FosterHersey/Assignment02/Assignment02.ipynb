# %% [markdown]
# ##Exercise
#
# The goal of this exercise is to combine the scoring and assists statistics for every player in the NBA in 2014-2015.  The end result will have them in a pandas dataframe with the fields from both pages for every player.

# %%
from bs4 import BeautifulSoup
from urllib2 import urlopen
from collections import OrderedDict
import pandas as adorable

URL_FORMAT_STRING = 'http://espn.go.com/nba/statistics/player/_/stat/%s/qualified/false'
SCORE_URL = URL_FORMAT_STRING % 'scoring-per-game'
ASSIST_URL = URL_FORMAT_STRING % 'assists'

# %% [markdown]
# The general steps should be as follows:

# %% [markdown]
# - Create a function get_cols that retrieves the names of the header columns given a table element (skip the ranks, split the positions)

# %%
# parse the column names into a list.
def parse_column_headers (table):
    header_cells = table.find(attrs={'class':'colhead'}).findAll('td')
    column_names = []
    for cell in header_cells:
        # skip rank
        if (cell.string == 'RK'):
            continue
        column_names.append(cell.string)
        # The column called PLAYER really has 2 fields of information,
        # the player and his position. When we encounter PLAYER,
        # push an additional column called POSITION on there.
        if (cell.string == 'PLAYER'):
            column_names.append(u'POSITION')
    return column_names

# %% [markdown]
# - Create a function get_data that retrieves the actual table data given a table element (skip the ranks, split the positions).  You can use either the dict approach or the numpy array approach.

# %%
# parse the player information from the table
def parse_player_data (field_names, table):
    players = []
    data_rows = table.findAll('tr')
    for row in data_rows:
        if row.attrs['class'][0] == 'colhead':
            continue

        data_cells = row.findAll('td')

        # take index 1 (player name + position in the same column, separated by ', ') and split it into 2 fields.
        player_and_position = map(lambda sub_cell: sub_cell.string.lstrip(', '), data_cells[1].contents)

        # start collecting the rest of attributes at index 2. index 0 is rank (which we skip)
        # and index 1 we handled specially
        rest_attributes = map(lambda i: data_cells[i].string, range(2, len(data_cells)))

        res = []
        res.extend(player_and_position)
        res.extend(rest_attributes)
        player_dict = OrderedDict(zip(field_names, res))
        players.append(player_dict)
    return players

# %% [markdown]
# - Write a python loop to loop through the various pages and call these functions on the appropriate urls so that you can retrieve every player (rather than just the top few).

# %% [markdown]
# - Repeat the above on both the scoring and assists URLs to get a pandas dataframe for both of them

# %%
def get_and_parse_espn_page_thingy (url):
    page = urlopen(url).read()
    soup = BeautifulSoup(page)
    table_el = soup.find(id='my-players-table').find('table')
    field_names = parse_column_headers(table_el)
    players = parse_player_data(field_names, table_el)

    next_page_button = soup.find('div', {'class':'jcarousel-next'})
    if 'jcarousel-next-disabled' not in next_page_button.attrs.get('class'):
        next_page_link = next_page_button.parent
        next_url = next_page_link.attrs.get('href')
        if next_url:
            players_from_next_page = get_and_parse_espn_page_thingy(next_url)
            players.extend(players_from_next_page)

    return players

# %%
player_scores_stats = get_and_parse_espn_page_thingy(SCORE_URL)
player_assists_stats = get_and_parse_espn_page_thingy(ASSIST_URL)

# %% [markdown]
# - Build dataframes for scores and assists

# %%
scores_keys = [k for k in player_scores_stats[0]]
scores_df = adorable.DataFrame(player_scores_stats, columns = scores_keys)

# %%
assists_keys = [k for k in player_assists_stats[0]]
assists_df = adorable.DataFrame(player_assists_stats, columns=assists_keys)

# %% [markdown]
# - Use the pandas.DataFrame.join() function to join your 2 pandas dataframes together and get a total result

# %%
merged = scores_df.merge(assists_df, on=['PLAYER','POSITION','TEAM'])
merged
# Out:
#                        PLAYER POSITION  TEAM GP_x MPG_x   PTS    FGM-FGA  \
# 0               Stephen Curry       PG    GS    5  32.0  35.8  11.6-20.2
# 1                Kevin Durant       SF   OKC    6  38.2  29.8  10.2-21.0
# 2               Blake Griffin       PF   LAC    5  34.6  28.2  11.2-19.0
# 3              Damian Lillard       PG   POR    6  36.7  27.3  10.0-21.3
# 4           Russell Westbrook       PG   OKC    6  36.0  27.2  10.2-21.2
# 5                Bradley Beal       SG   WSH    4  35.3  25.3   9.5-20.0
# 6                James Harden       SG   HOU    5  39.0  23.8   6.0-20.4
# 7               Isaiah Thomas       PG   BOS    4  30.3  23.5   7.5-18.0
# 8                LeBron James       SF   CLE    5  33.8  22.2   9.4-19.2
# 9                 Dwyane Wade       SG   MIA    5  30.2  22.2   8.0-16.2
# 10              DeMar DeRozan       SG   TOR    5  35.0  22.2   6.4-15.2
# 11              C.J. McCollum       SG   POR    6  34.3  22.2   8.5-18.0
# 12           DeMarcus Cousins       PF   SAC    3  26.0  22.0   7.0-16.7
# 13            Carmelo Anthony       SF    NY    5  33.8  21.8   7.0-19.2
# 14               Jimmy Butler       SG   CHI    6  36.0  21.7   7.0-15.0
# 15              Kawhi Leonard       SF    SA    5  33.2  21.6   9.0-18.8
# 16      Giannis Antetokounmpo       SF   MIL    4  37.5  21.3   8.0-13.5
# 17                  John Wall       PG   WSH    4  36.0  20.8   6.8-15.3
# 18              Anthony Davis       PF    NO    4  37.3  20.8   6.3-16.5
# 19               Eric Bledsoe       PG   PHX    5  33.4  20.6   7.2-16.8
# 20              Evan Fournier       SF   ORL    5  39.0  20.6   8.0-16.8
# 21             Andre Drummond        C   DET    4  39.0  20.3   7.8-15.8
# 22              Jahlil Okafor        C   PHI    4  34.0  20.3   8.5-15.5
# 23                Brook Lopez        C   BKN    5  32.8  20.0   7.4-13.0
# 24                Greg Monroe        C   MIL    5  34.8  19.8   7.8-13.2
# 25                 Kyle Lowry       PG   TOR    5  34.6  19.2   6.0-13.4
# 26                Jeff Teague       PG   ATL    6  31.7  19.2   6.5-14.0
# 27             Reggie Jackson       PG   DET    4  33.8  19.0   7.0-17.0
# 28               Kevin Martin       SG   MIN    4  28.0  18.8   5.3-11.5
# 29                Paul George       SF   IND    5  34.8  18.6   5.6-15.6
# ..                        ...      ...   ...  ...   ...   ...        ...
# 369               Chuck Hayes       PF   HOU    1   9.0   0.0    0.0-0.0
# 370                 Omer Asik        C    NO    1  10.0   0.0    0.0-0.0
# 371                Sasha Kaun        C   CLE    2   3.5   0.0    0.0-0.0
# 372  Luc Richard Mbah a Moute       PF   LAC    3   2.7   0.0    0.0-0.3
# 373              DeJuan Blair        C   WSH    1   4.0   0.0    0.0-1.0
# 374             James Johnson       PF   TOR    3   4.3   0.0    0.0-0.0
# 375            Garrett Temple       SG   WSH    2   1.5   0.0    0.0-0.0
# 376            Pablo Prigioni       PG   LAC    1   7.0   0.0    0.0-4.0
# 377       Kostas Papanikolaou       SF   DEN    1   1.0   0.0    0.0-0.0
# 378              Shelvin Mack       PG   ATL    1   8.0   0.0    0.0-2.0
# 379                Quincy Acy       SF   SAC    1   4.0   0.0    0.0-0.0
# 380          Andrew Nicholson       PF   ORL    1   4.0   0.0    0.0-1.0
# 381               Jeff Withey        C  UTAH    1   1.0   0.0    0.0-0.0
# 382               Erick Green       PG   DEN    3   2.3   0.0    0.0-0.3
# 383               Tim Frazier       PG   POR    3   3.7   0.0    0.0-0.3
# 384              Solomon Hill       SF   IND    1   2.0   0.0    0.0-0.0
# 385              Mike Muscala       PF   ATL    2   5.0   0.0    0.0-1.0
# 386        Shayne Whittington       PF   IND    1   2.0   0.0    0.0-0.0
# 387                 Joe Young       PG   IND    2   2.0   0.0    0.0-0.0
# 388            Reggie Bullock       SF   DET    3   8.3   0.0    0.0-1.3
# 389               James Ennis       SF   MIA    2   2.0   0.0    0.0-0.0
# 390           Josh Richardson       SG   MIA    1   7.0   0.0    0.0-1.0
# 391            Jarnell Stokes       PF   MEM    1   3.0   0.0    0.0-0.0
# 392               Salah Mejri        C   DAL    3   3.3   0.0    0.0-0.3
# 393              Mitch McGary       PF   OKC    1   4.0   0.0    0.0-0.0
# 394                Sam Dekker       SF   HOU    2   3.0   0.0    0.0-0.0
# 395             Cameron Payne       PG   OKC    1   4.0   0.0    0.0-0.0
# 396              Delon Wright       PG   TOR    1   2.0   0.0    0.0-1.0
# 397              Terry Rozier       PG   BOS    2   4.0   0.0    0.0-3.0
# 398           Kelly Oubre Jr.       SF   WSH    1   1.0   0.0    0.0-0.0
#
#       FG%   3PM-3PA   3P%    FTM-FTA    FT% GP_y MPG_y AST   APG  TO TOPG  \
# 0    .574  5.6-10.8  .519    7.0-7.4   .946    5  32.0  29   5.8   8  1.6
# 1    .484   2.8-6.7  .425    6.7-7.5   .889    6  38.2  16   2.7  14  2.3
# 2    .589   0.0-0.4  .000    5.8-7.6   .763    5  34.6  20   4.0  10  2.0
# 3    .469   3.8-9.0  .426    3.5-4.0   .875    6  36.7  40   6.7  24  4.0
# 4    .480   1.8-5.3  .344    5.0-5.8   .857    6  36.0  63  10.5  32  5.3
# 5    .475   3.3-7.0  .464    3.0-4.0   .750    4  35.3   7   1.8  11  2.8
# 6    .294  1.8-11.0  .164  10.0-11.8   .847    5  39.0  25   5.0  21  4.2
# 7    .417   1.8-5.5  .318    6.8-7.3   .931    4  30.3  26   6.5  13  3.3
# 8    .490   0.4-3.6  .111    3.0-5.4   .556    5  33.8  28   5.6  14  2.8
# 9    .494   1.0-2.0  .500    5.2-6.2   .839    5  30.2  21   4.2  15  3.0
# 10   .421   0.4-1.4  .286   9.0-11.0   .818    5  35.0  21   4.2  12  2.4
# 11   .472   3.0-6.5  .462    2.2-2.7   .813    6  34.3  21   3.5  11  1.8
# 12   .420   1.3-3.3  .400    6.7-9.0   .741    3  26.0   7   2.3  10  3.3
# 13   .365   1.6-5.0  .320    6.2-7.0   .886    5  33.8  18   3.6   7  1.4
# 14   .467   2.0-3.5  .571    5.7-6.8   .829    6  36.0  16   2.7   2  0.3
# 15   .479   0.8-3.2  .250    2.8-2.8  1.000    5  33.2   4   0.8  12  2.4
# 16   .593   1.0-2.0  .500    4.3-5.3   .810    4  37.5  10   2.5  13  3.3
# 17   .443   1.5-4.8  .316    5.8-8.0   .719    4  36.0  33   8.3  15  3.8
# 18   .379   1.0-2.8  .364   7.3-10.0   .725    4  37.3   7   1.8  12  3.0
# 19   .429   1.0-3.6  .278    5.2-6.8   .765    5  33.4  28   5.6  14  2.8
# 20   .476   2.2-6.4  .344    2.4-3.4   .706    5  39.0  14   2.8   7  1.4
# 21   .492   0.0-0.0  .000    4.8-8.3   .576    4  39.0   3   0.8   9  2.3
# 22   .548   0.0-0.0  .000    3.3-4.0   .813    4  34.0   2   0.5  13  3.3
# 23   .569   0.0-0.2  .000    5.2-6.6   .788    5  32.8  10   2.0  11  2.2
# 24   .591   0.0-0.0  .000    4.2-5.2   .808    5  34.8  17   3.4   8  1.6
# 25   .448   2.0-4.6  .435    5.2-6.2   .839    5  34.6  33   6.6  18  3.6
# 26   .464   0.8-2.8  .294    5.3-6.2   .865    6  31.7  35   5.8  17  2.8
# 27   .412   1.5-3.8  .400    3.5-4.5   .778    4  33.8  22   5.5  17  4.3
# 28   .457   0.8-3.3  .231    7.5-8.8   .857    4  28.0   2   0.5   7  1.8
# 29   .359   1.8-6.2  .290    5.6-6.4   .875    5  34.8  23   4.6  16  3.2
# ..    ...       ...   ...        ...    ...  ...   ...  ..   ...  ..  ...
# 369  .000   0.0-0.0  .000    0.0-0.0   .000    1   9.0   0   0.0   0  0.0
# 370  .000   0.0-0.0  .000    0.0-0.0   .000    1  10.0   0   0.0   0  0.0
# 371  .000   0.0-0.0  .000    0.0-0.0   .000    2   3.5   1   0.5   1  0.5
# 372  .000   0.0-0.0  .000    0.0-0.0   .000    3   2.7   1   0.3   0  0.0
# 373  .000   0.0-0.0  .000    0.0-0.0   .000    1   4.0   0   0.0   2  2.0
# 374  .000   0.0-0.0  .000    0.0-0.0   .000    3   4.3   1   0.3   1  0.3
# 375  .000   0.0-0.0  .000    0.0-0.0   .000    2   1.5   1   0.5   0  0.0
# 376  .000   0.0-3.0  .000    0.0-0.0   .000    1   7.0   1   1.0   1  1.0
# 377  .000   0.0-0.0  .000    0.0-0.0   .000    1   1.0   0   0.0   0  0.0
# 378  .000   0.0-0.0  .000    0.0-0.0   .000    1   8.0   0   0.0   2  2.0
# 379  .000   0.0-0.0  .000    0.0-0.0   .000    1   4.0   1   1.0   0  0.0
# 380  .000   0.0-0.0  .000    0.0-0.0   .000    1   4.0   0   0.0   1  1.0
# 381  .000   0.0-0.0  .000    0.0-0.0   .000    1   1.0   0   0.0   0  0.0
# 382  .000   0.0-0.3  .000    0.0-0.0   .000    3   2.3   1   0.3   0  0.0
# 383  .000   0.0-0.0  .000    0.0-0.0   .000    3   3.7   1   0.3   1  0.3
# 384  .000   0.0-0.0  .000    0.0-0.0   .000    1   2.0   0   0.0   0  0.0
# 385  .000   0.0-0.5  .000    0.0-0.0   .000    2   5.0   0   0.0   1  0.5
# 386  .000   0.0-0.0  .000    0.0-0.0   .000    1   2.0   0   0.0   2  2.0
# 387  .000   0.0-0.0  .000    0.0-0.0   .000    2   2.0   0   0.0   1  0.5
# 388  .000   0.0-1.0  .000    0.0-0.0   .000    3   8.3   0   0.0   0  0.0
# 389  .000   0.0-0.0  .000    0.0-0.0   .000    2   2.0   1   0.5   0  0.0
# 390  .000   0.0-0.0  .000    0.0-0.0   .000    1   7.0   0   0.0   1  1.0
# 391  .000   0.0-0.0  .000    0.0-0.0   .000    1   3.0   0   0.0   0  0.0
# 392  .000   0.0-0.0  .000    0.0-0.0   .000    3   3.3   0   0.0   0  0.0
# 393  .000   0.0-0.0  .000    0.0-0.0   .000    1   4.0   0   0.0   2  2.0
# 394  .000   0.0-0.0  .000    0.0-0.0   .000    2   3.0   0   0.0   0  0.0
# 395  .000   0.0-0.0  .000    0.0-0.0   .000    1   4.0   3   3.0   0  0.0
# 396  .000   0.0-1.0  .000    0.0-0.0   .000    1   2.0   0   0.0   1  1.0
# 397  .000   0.0-0.5  .000    0.0-0.0   .000    2   4.0   0   0.0   2  1.0
# 398  .000   0.0-0.0  .000    0.0-0.0   .000    1   1.0   0   0.0   0  0.0
#
#     AP48M AST/TO
# 0     8.7   3.63
# 1     3.4   1.14
# 2     5.5   2.00
# 3     8.7   1.67
# 4    14.0   1.97
# 5     2.4   0.64
# 6     6.2   1.19
# 7    10.3   2.00
# 8     8.0   2.00
# 9     6.7   1.40
# 10    5.8   1.75
# 11    4.9   1.91
# 12    4.3   0.70
# 13    5.1   2.57
# 14    3.6   8.00
# 15    1.2   0.33
# 16    3.2   0.77
# 17   11.0   2.20
# 18    2.3   0.58
# 19    8.0   2.00
# 20    3.4   2.00
# 21    0.9   0.33
# 22    0.7   0.15
# 23    2.9   0.91
# 24    4.7   2.13
# 25    9.2   1.83
# 26    8.8   2.06
# 27    7.8   1.29
# 28    0.9   0.29
# 29    6.3   1.44
# ..    ...    ...
# 369   0.0   0.00
# 370   0.0   0.00
# 371   6.9   1.00
# 372   6.0   0.00
# 373   0.0   0.00
# 374   3.7   1.00
# 375  16.0   0.00
# 376   6.9   1.00
# 377   0.0   0.00
# 378   0.0   0.00
# 379  12.0   0.00
# 380   0.0   0.00
# 381   0.0   0.00
# 382   6.9   0.00
# 383   4.4   1.00
# 384   0.0   0.00
# 385   0.0   0.00
# 386   0.0   0.00
# 387   0.0   0.00
# 388   0.0   0.00
# 389  12.0   0.00
# 390   0.0   0.00
# 391   0.0   0.00
# 392   0.0   0.00
# 393   0.0   0.00
# 394   0.0   0.00
# 395  36.0   0.00
# 396   0.0   0.00
# 397   0.0   0.00
# 398   0.0   0.00
#
# [399 rows x 20 columns]
